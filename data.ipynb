# %% [markdown]
# ## DATASET CHECK

# %%
import pandas as pd
import string

# %%
# all_letters = string.ascii_letters + "0123456789 .,;'-_()[]@*$#%?!^<>\"`=+&~|:/\\"
all_letters = string.digits + string.ascii_letters + string.punctuation + '\n'

# %%
all_letters
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n'

# %%
filename = r'Dataset/all.txt'
text = []

# %%
with open(filename) as f:
    lines = [line.rstrip('\n') for line in f]

# %%
lines
# Out:
# ['rlkj@1980',
#  'tp@12345678',
#  'M!$$y2005',
#  'IM1n1raq!!',
#  'n#wlif07',
#  'acorn123!',
#  '521@843',
#  '500049@vikas',
#  'Ranger#2',
#  'sw33tb@by',
#  'dod896@l1',
#  'India@123456',
#  'tvicky_38',
#  '55296 -',
#  'adr_123',
#  '5.bigdog.6',
#  'Por$c#301',
#  'Jay1026.',
#  'queens-08',
#  'Ma%%32Fn',
#  '12-guage',
#  'Slvr540!!',
#  'Aziza@444',
#  'xyzzy@42',
#  'ABcd!@3456',
#  '141414!',
#  '!7Eezbutz',
#  'komal@1889',
#  'atl678*',
#  'sarabeee#0',
#  'aghg.d]hk123',
#  'Max$56li',
#  'lexi01*',
#  'spike10^',
#  'riz_123',
#  '*mineonly1',
#  'fucker-8',
#  'v-dogg651',
#  'nannu_333',
#  'shift_1',
#  'yankee1!',
#  '@>-; j2',
#  'JAIMINE.18301',
#  'Hmfogtliwt1!',
#  'vmfa=332',
#  'Randy&Ann1',
#  '1qaz@WSX3edc',
#  '$ow3ll01',
#  'dilldo_41364',
#  'n@t@li3',
#  'mustang87*',
#  'maxie_115',
#  '69longpole^',
#  'ang#1010',
#  '12!@asAS2',
#  '*deniro321*',
#  'integra_11',
#  '06.08.74',
#  '111111a/b',
#  '$rwm1446',
#  'Yz250cc!',
#  'EL.rjel.78',
# ...

# %%
data = pd.DataFrame(lines, columns=['Lines'])

# %%
data.describe()
# Out:
#            Lines
# count     414506
# unique    375853
# top     lisa6/29
# freq           4

# %%
data = data.drop_duplicates()

# %%
data.describe()
# Out:
#             Lines
# count      375853
# unique     375853
# top     rlkj@1980
# freq            1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 375853 entries, 0 to 376825
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Lines   375853 non-null  object
# dtypes: object(1)
# memory usage: 5.7+ MB

# %%
lines = data['Lines'].to_list()
lines
# Out:
# ['rlkj@1980',
#  'tp@12345678',
#  'M!$$y2005',
#  'IM1n1raq!!',
#  'n#wlif07',
#  'acorn123!',
#  '521@843',
#  '500049@vikas',
#  'Ranger#2',
#  'sw33tb@by',
#  'dod896@l1',
#  'India@123456',
#  'tvicky_38',
#  '55296 -',
#  'adr_123',
#  '5.bigdog.6',
#  'Por$c#301',
#  'Jay1026.',
#  'queens-08',
#  'Ma%%32Fn',
#  '12-guage',
#  'Slvr540!!',
#  'Aziza@444',
#  'xyzzy@42',
#  'ABcd!@3456',
#  '141414!',
#  '!7Eezbutz',
#  'komal@1889',
#  'atl678*',
#  'sarabeee#0',
#  'aghg.d]hk123',
#  'Max$56li',
#  'lexi01*',
#  'spike10^',
#  'riz_123',
#  '*mineonly1',
#  'fucker-8',
#  'v-dogg651',
#  'nannu_333',
#  'shift_1',
#  'yankee1!',
#  '@>-; j2',
#  'JAIMINE.18301',
#  'Hmfogtliwt1!',
#  'vmfa=332',
#  'Randy&Ann1',
#  '1qaz@WSX3edc',
#  '$ow3ll01',
#  'dilldo_41364',
#  'n@t@li3',
#  'mustang87*',
#  'maxie_115',
#  '69longpole^',
#  'ang#1010',
#  '12!@asAS2',
#  '*deniro321*',
#  'integra_11',
#  '06.08.74',
#  '111111a/b',
#  '$rwm1446',
#  'Yz250cc!',
#  'EL.rjel.78',
# ...

# %%
with open('all.txt', 'w') as filehandle:
    for listitem in lines:
        filehandle.write('%s\n' % listitem)

# %%
print(type(all_letters))
# Out:
# <class 'str'>
